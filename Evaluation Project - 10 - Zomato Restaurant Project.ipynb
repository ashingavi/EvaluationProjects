# %% [markdown]
# ### Evaluation Project - 10
# # Zomato Restaurant Project
# ### Problem Statement:
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# ### Data Storage:
# This problem statement contains two datasets- **Zomato.csv** and **country_code.csv**.
# **Country_code.csv** contains two variables:
#  Country code
#  Country name
# The collected data has been stored in the Comma Separated Value file **Zomato.csv**. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the
# following variables:
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people
#
#
# **Problem statement : In this dataset predict 2 things –**
# 1) Average Cost for two
# 2) Price range
#
# **Hint** : Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets
#
# #### Downlaod Files:
#
#     https://github.com/dsrscientist/dataset4/blob/main/Country-Code.xlsx
#     https://github.com/dsrscientist/dataset4/blob/main/zomato.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import codecs
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv',encoding="latin-1")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# All other columns have 0 null values except Cuisines.

# %%
df.dropna()
df.reset_index()
# Out:
#       index  Restaurant ID           Restaurant Name  Country Code  \
# 0         0        6317637          Le Petit Souffle           162
# 1         1        6304287          Izakaya Kikufuji           162
# 2         2        6300002    Heat - Edsa Shangri-La           162
# 3         3        6318506                      Ooma           162
# 4         4        6314302               Sambo Kojin           162
# ...     ...            ...                       ...           ...
# 9546   9546        5915730              NamlÛ± Gurme           208
# 9547   9547        5908749             Ceviz AÛôacÛ±           208
# 9548   9548        5915807                     Huqqa           208
# 9549   9549        5916112              Aôôk Kahve           208
# 9550   9550        5927402  Walter's Coffee Roastery           208
#
#                   City                                            Address  \
# 0          Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
# Checking null values in our dataset
null = df.isnull().sum()
print(null)
plt.figure(figsize=[15,5], facecolor = 'lightgreen')
sns.heatmap(df.isnull(), cmap = 'cool')
plt.title(("Null Values - Heat Map"), fontsize = 25)
plt.show()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#Checking other DataFrame of Country Name and Code

df_1 = pd.read_excel('Country-Code-1.xlsx')
df_1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
data = pd.merge(df,df_1,on='Country Code',how='left')

# %%
data.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %%
for i in data.columns:
    print(data[i].value_counts())
    print('======================================')
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
# ...
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# ...
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
# ...
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# ...

# %%
# Droping 'Switch to Order menu as it has same values, so further it will not be required.
data = data.drop(['Switch to order menu'],axis=1)

# %% [markdown]
# # EDA - Exploratory Data ANALYSIS

# %%
# Country
print ('*************************')
print(data['Country'].value_counts())
print ('*************************')
print(data['Country'].value_counts().sum(), ' = Total')
print ('*************************', '\n')
plt.figure(figsize=(20,7), facecolor = 'silver')
sns.countplot( x = 'Country',data = data, palette = 'prism')
plt.title('Country Wise Count',fontsize=20)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(fontsize = 15, rotation = 90)
plt.yticks(fontsize = 15)
plt.show()
# Out:
# *************************
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64
# *************************
# 9551  = Total
# *************************

# %% [markdown]
# Observation - Indian have way more users than any other countries combined together further united states and united kingdom are on 2nd and 3rd postion respectively.

# %%
# Grouping Ratings related columns
Ratngs = data.groupby(['Aggregate rating','Rating color',
                       'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
Ratngs
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
plt.figure(figsize=(20,7), facecolor = 'silver')
sns.barplot(x="Aggregate rating",y="Rating Count",data=Ratngs)
plt.title('Ratings', fontsize = 20)
plt.show()

# %% [markdown]
# Observation - Most of the people havent provided any rating, while most number of people have given 3.2 and 3.1 ratings.

# %%
# Grouping Cities
city = data.groupby(['City']).size().reset_index().rename(columns={0:'Count'})
city = city.sort_values(by=['Count'], ascending = False)

# %%
a = city[:10]
a
# Out:
#             City  Count
# 88     New Delhi   5473
# 50       Gurgaon   1118
# 89         Noida   1080
# 43     Faridabad    251
# 48     Ghaziabad     25
# 17  Bhubaneshwar     21
# 69       Lucknow     21
# 5       Amritsar     21
# 2      Ahmedabad     21
# 51      Guwahati     21

# %%
plt.figure(figsize=(20,7), facecolor = 'silver')
sns.barplot(x="City", y = 'Count', data = a)
plt.title('Ratings', fontsize = 20)
plt.show()

# %%
cuisines = data.groupby(['Cuisines']).size().reset_index().rename(columns={0:'Count'})
cuisines = cuisines.sort_values(by=['Count'], ascending = False)

# %%
b = cuisines[:10]
b
# Out:
#                             Cuisines  Count
# 1306                    North Indian    936
# 1329           North Indian, Chinese    511
# 497                          Chinese    354
# 828                        Fast Food    354
# 1514           North Indian, Mughlai    334
# 331                             Cafe    299
# 177                           Bakery    218
# 1520  North Indian, Mughlai, Chinese    197
# 186                 Bakery, Desserts    170
# 1749                     Street Food    149

# %%
plt.figure(figsize=(20,7), facecolor = 'silver')
sns.barplot(x="Cuisines", y = 'Count', data = b)
plt.title('Ratings', fontsize = 20)
plt.xticks(fontsize = 15, rotation = 90)
plt.show()

# %%
# Comparision of Aggregate rating with price
plt.figure(figsize=(20,7),facecolor = 'lightgreen')
sns.scatterplot( x = 'Aggregate rating',y = 'Average Cost for two',data = data, palette = 'winter', hue = 'Rating text')
plt.title('Comparision of Aggregate rating with price',fontsize=20)
plt.xlabel('Aggregate rating',fontsize=15)
plt.ylabel('Average Cost for two',fontsize=15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
# Comparision of Aggregate rating with price
plt.figure(figsize=(20,7),facecolor = 'lightblue')
sns.scatterplot( y = 'Average Cost for two',x = 'Rating text',data = data, palette = 'winter', hue = 'Rating text')
plt.title('Comparision Rating with Average cost for two',fontsize=20)
plt.ylabel('Average Cost for Two',fontsize=15)
plt.xlabel('Rating text',fontsize=15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
# Comparision of Aggregate rating with price
plt.figure(figsize=(20,7),facecolor = 'lightyellow')
sns.scatterplot( y = 'Votes',x = 'Country',data = data, hue = 'Rating text',palette = 'winter')
plt.title('Country wise votes',fontsize=20)
plt.ylabel('Count of Votes',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.xticks(fontsize = 15, rotation = 90)
plt.yticks(fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(20,7),facecolor = 'lightblue')
sns.scatterplot(data['Country'],data['Aggregate rating'],hue = 'Rating text',data = data)
plt.show()

# %%
# ploting numerical columns
plt.figure(figsize = (20,25), facecolor = 'lightgreen')
for i in enumerate(df.select_dtypes(include=['int64','float','int32'])):
    plt.subplot(4,2,i[0]+1)
    sns.distplot(data[i[1]],color='m')

# %% [markdown]
# # Checking Outliers

# %%
plt.figure(figsize=(20,30))
for i in enumerate(df.select_dtypes(include=['int64','float','int32'])):
    plt.subplot(4,2,i[0]+1)
    sns.boxplot(data[i[1]])

# %% [markdown]
# There are outliers in our data

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# ### Z - Score

# %%
from scipy.stats import zscore

z = np.abs(zscore(data.select_dtypes(include=['int64','float','int32'])))

print(np.where(z>3))
# Out:
# (array([  22,   23,   24, ..., 9548, 9549, 9550], dtype=int64), array([3, 3, 3, ..., 1, 1, 1], dtype=int64))

# %%
data_new = data [(z<3).all(axis=1)]
print(("with outliers::",data.shape))
print("After removing outliers::",data_new.shape)
# Out:
# ('with outliers::', (9551, 21))
# After removing outliers:: (8565, 21)

# %%
dataloss = (9551-8565)*100/9551
print ('DATA LOSS = ', dataloss, '%')
# Out:
# DATA LOSS =  10.323526332321222 %

# %%
data = data_new

# %%
df.select_dtypes(include=['int64','float','int32']).skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    35.477915
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %%
from sklearn.preprocessing import power_transform

# %%
data[['Average Cost for two','Votes','Country Code']]=power_transform(
     data[['Average Cost for two','Votes','Country Code']],method='yeo-johnson')

# %% [markdown]
# ## LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
cat_data = data.select_dtypes(exclude=['int64','float','int32'])
for val in cat_data:
    data[val]=le.fit_transform(data[val].astype(str))

# %% [markdown]
# ## Correlation

# %%
data.corr()
# Out:
#                       Restaurant ID  Restaurant Name  Country Code      City  \
# Restaurant ID              1.000000         0.002933      0.036657  0.010785
# Restaurant Name            0.002933         1.000000      0.012685  0.008530
# Country Code               0.036657         0.012685      1.000000  0.020689
# City                       0.010785         0.008530      0.020689  1.000000
# Address                    0.145534         0.001829     -0.021613 -0.095810
# Locality                   0.090610         0.008659     -0.028893 -0.029670
# Locality Verbose           0.090699         0.008637     -0.028208 -0.033822
# Longitude                 -0.159271         0.016053      0.100383  0.036121
# Latitude                  -0.145940         0.012006     -0.155668  0.046024
# Cuisines                  -0.059961         0.060831     -0.020096  0.014873
# Average Cost for two      -0.131635         0.057662     -0.042949 -0.085190
# ...

# %%
plt.figure (figsize = (20,15))
plt.title('Correlation HeatMap', fontsize = 15)
sns.heatmap(data.corr(), annot = True , linewidths = 4, linecolor='black',fmt='.2f')
plt.show()

# %%
# Checking correlation of all features with Price range

plt.figure(figsize = (15,8))
data.corr()['Price range'].sort_values(ascending=False).drop(['Price range']).plot.bar()
plt.xlabel("Price range", fontsize = 14)
plt.ylabel("correlation with Price range", fontsize = 18)
plt.title ("Correction of all features with Price range", fontsize = 25)
plt.show()

# %% [markdown]
# ### Observation
# 1. AverageCost for two have most positive correlation with price range which is our target column.
# 2. It is folloed by Has Table booking.
# 3. Restuarant ID have neagtive correlation with our target column.
# 4. Cuisines, Is Delivering now, address, currecenly have least correlation with our target column.

# %%
data_reg = data

# %% [markdown]
# # 1) Price range

# %% [markdown]
# ### Dividng columns to X and Y

# %%
x = data.drop(['Price range'],axis=1)
y = data['Price range']
x
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3321     11.616899    27     7731        98
# 1           6304287             2794     11.616899    27     5244       376
# 2           6300002             2550     11.616899    28     3955       185
# 3           6318506             4150     11.616899    28     7736       549
# 4           6314302             4878     11.616899    28     7735       549
# ...             ...              ...           ...   ...      ...       ...
# 9432        6201972             1947     11.616899    13     1344       717
# 9433        6201130             6352     11.616899    13      835       736
# 9434       18261203             4824     11.616899    13     4700       742
# 9435        6201360             4253     11.616899    13     3211       759
# 9436       18318801             4767     11.616899    13     7592       759
#
# ...

# %% [markdown]
# ## StandardScaler

# %%
# Importing SandardScaler
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#       Restaurant ID  Restaurant Name  Country Code      City   Address  \
# 0         -0.277386         0.052689     11.616901 -0.498280  1.612139
# 1         -0.278877        -0.226145     11.616901 -0.498280  0.523697
# 2         -0.279356        -0.355245     11.616901 -0.381656 -0.040436
# 3         -0.277289         0.491312     11.616901 -0.381656  1.614327
# 4         -0.277759         0.876496     11.616901 -0.381656  1.613889
# ...             ...              ...           ...       ...       ...
# 8560      -0.290304        -0.674292     11.616901 -2.131029 -1.183147
# 8561      -0.290398         1.656387     11.616901 -2.131029 -1.405912
# 8562       1.056489         0.847925     11.616901 -2.131029  0.285615
# 8563      -0.290372         0.545809     11.616901 -2.131029 -0.366050
# 8564       1.062922         0.817766     11.616901 -2.131029  1.551305
#
#       Locality  Locality Verbose  Longitude  Latitude  Cuisines  \
# ...

# %% [markdown]
# ## Variance Inflation Factor (VIF)

# %%
# Importing Variance Inflation Factor
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["variables"] = x.columns
vif["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]

# %%
x.drop("Locality Verbose",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["variables"] = x.columns
vif["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]

# %%
x.drop("Country Code",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["variables"] = x.columns
vif["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif
# Out:
#                variables       VIF
# 0          Restaurant ID  1.556581
# 1        Restaurant Name  1.009017
# 2                   City  1.072869
# 3                Address  1.066315
# 4               Locality  1.055393
# 5              Longitude  8.541434
# 6               Latitude  8.689275
# 7               Cuisines  1.027442
# 8   Average Cost for two  1.899807
# 9               Currency  1.481634
# 10     Has Table booking  1.538345
# 11   Has Online delivery  1.274118
# 12     Is delivering now  1.015762
# 13      Aggregate rating  5.230681
# 14          Rating color  1.253388
# 15           Rating text  1.583290
# 16                 Votes  6.403671
# 17               Country  1.410314

# %% [markdown]
# # Checking Best RandomState

# %%
# Importing RandomForest, train_test_split and accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
MAX_Acc = 0
MAX_RS = 0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20, random_state =i)
    RFC = RandomForestClassifier()
    RFC.fit(x_train,y_train)
    prediction = RFC.predict(x_test)
    acc = accuracy_score(y_test, prediction)
    if acc > MAX_Acc:
        MAX_Acc = acc
        MAX_RS = i
print("Best accuracy is ",MAX_Acc," for Random state ",MAX_RS)
# Out:
# Best accuracy is  0.9912434325744308  for Random state  17

# %%
# Spliting data into train and test using best random_state
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20, random_state = MAX_RS)

# %% [markdown]
# # Building Models
#
# ## Classicification problem
# - **LogisticRegression**
#
# - **KNeighborsClassifier**
#
# - **DecisionTreeClassifier**
#
# - **RandomForestClassifier**
#
# - **SVC**
#
# - **AdaBoostClassifier**

# %%
# Importing LogisticRegression, KNeighborsClassifier, DecisionTreeClassifier, RandomForestClassifier, 
# SVC and AdaBoostClassifier

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state = MAX_RS)

models = [LogisticRegression(),KNeighborsClassifier(),DecisionTreeClassifier(),RandomForestClassifier(),SVC(),AdaBoostClassifier()]
for model in models:
    model.fit(x_train,y_train)
    predlr = model.predict(x_train)
    print("Model Name",model)
    print("Accuracy",accuracy_score(y_train,predlr)*100)
    print(confusion_matrix(y_train,predlr))
    print(classification_report(y_train,predlr))
    print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>','\n')
# Out:
# Model Name LogisticRegression()
# Accuracy 96.17629889083479
# [[3385   34    0    0]
#  [  36 2188   32    0]
#  [   0   84  751   20]
#  [   0    0   56  266]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      3419
#            2       0.95      0.97      0.96      2256
#            3       0.90      0.88      0.89       855
#            4       0.93      0.83      0.88       322
#
#     accuracy                           0.96      6852
#    macro avg       0.94      0.92      0.93      6852
# weighted avg       0.96      0.96      0.96      6852
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Model Name KNeighborsClassifier()
# Accuracy 85.3035610040864
# [[3184  234    1    0]
#  [ 293 1864   99    0]
#  [  13  205  619   18]
#  [   1   27  116  178]]
#               precision    recall  f1-score   support
#
#            1       0.91      0.93      0.92      3419
# ...

# %% [markdown]
# ## Cross Validation Score

# %%
# Importing Cross_val_score fromm sklearn
from sklearn.model_selection import cross_val_score

# %%
# LogisticRegression, KNeighborsClassifier, DecisionTreeClassifier, RandomForestClassifier, SVC, AdaBoostClassifier
models=[LogisticRegression(),KNeighborsClassifier(),DecisionTreeClassifier(),RandomForestClassifier(),SVC(),AdaBoostClassifier()]
for model in models:
    scr = cross_val_score(model,x,y,cv=5)
    print("Model Name :",model)
    print("Cross validation score is: ", scr.mean()*100)
    print("Mean score :", (scr.mean())*100)
    print("STD :", scr.std()*100)
    print('===============================================')
# Out:
# Model Name : LogisticRegression()
# Cross validation score is:  95.13134851138354
# Mean score : 95.13134851138354
# STD : 2.7142785282453517
# ...
# Model Name : KNeighborsClassifier()
# Cross validation score is:  71.97898423817864
# Mean score : 71.97898423817864
# STD : 5.469907749132085
# ...
# Model Name : DecisionTreeClassifier()
# Cross validation score is:  87.61237594862814
# Mean score : 87.61237594862814
# STD : 20.694021563287933
# ...
# Model Name : RandomForestClassifier()
# Cross validation score is:  96.43899591360187
# Mean score : 96.43899591360187
# STD : 3.6732150701625144
# ...
# Model Name : SVC()
# Cross validation score is:  91.43023934617631
# Mean score : 91.43023934617631
# STD : 4.7979313299083355
# ...
# Model Name : AdaBoostClassifier()
# Cross validation score is:  71.32516053706948
# Mean score : 71.32516053706948
# STD : 22.53185478464708
# ...

# %% [markdown]
# ## Hyper Parameter Tunning

# %%
# Importing GridSearchCV for Hyper Parameter Tunning
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'criterion':['gini'], 'max_features':['auto'], 'n_estimators':[0,200], 'max_depth':[2,3,4,5,6,8]}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameters,cv = 5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini'], 'max_depth': [2, 3, 4, 5, 6, 8],
#                          'max_features': ['auto'], 'n_estimators': [0, 200]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
Price_range = RandomForestClassifier (criterion='gini', max_depth=8, max_features='auto', n_estimators=200)
Price_range.fit(x_train, y_train)
pred = Price_range.predict(x_train)
acc=accuracy_score(y_train,pred)
print("Accuracy after tuning:",acc*100,"%")
# Out:
# Accuracy after tuning: 99.21190893169877 %

# %%
Price_range = RandomForestClassifier (criterion='gini', max_depth=8, max_features='auto', n_estimators=200)
Price_range.fit(x_train, y_train)
pred = Price_range.predict(x_test)
acc=accuracy_score(y_test,pred)
print("Accuracy after tuning:",acc*100,"%")
# Out:
# Accuracy after tuning: 98.24868651488616 %

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(Price_range,"Price_range.pkl")
# Out:
# ['Price_range.pkl']

# %% [markdown]
# # 2. Average Cost for two

# %%
data_reg
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3321     11.616899    27     7731        98
# 1           6304287             2794     11.616899    27     5244       376
# 2           6300002             2550     11.616899    28     3955       185
# 3           6318506             4150     11.616899    28     7736       549
# 4           6314302             4878     11.616899    28     7735       549
# ...             ...              ...           ...   ...      ...       ...
# 9432        6201972             1947     11.616899    13     1344       717
# 9433        6201130             6352     11.616899    13      835       736
# 9434       18261203             4824     11.616899    13     4700       742
# 9435        6201360             4253     11.616899    13     3211       759
# 9436       18318801             4767     11.616899    13     7592       759
#
# ...

# %%
# Distributing column X and Y
X = data_reg.drop('Average Cost for two',axis=1)
Y = data_reg['Average Cost for two']
X # (checking X)
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3321     11.616899    27     7731        98
# 1           6304287             2794     11.616899    27     5244       376
# 2           6300002             2550     11.616899    28     3955       185
# 3           6318506             4150     11.616899    28     7736       549
# 4           6314302             4878     11.616899    28     7735       549
# ...             ...              ...           ...   ...      ...       ...
# 9432        6201972             1947     11.616899    13     1344       717
# 9433        6201130             6352     11.616899    13      835       736
# 9434       18261203             4824     11.616899    13     4700       742
# 9435        6201360             4253     11.616899    13     3211       759
# 9436       18318801             4767     11.616899    13     7592       759
#
# ...

# %% [markdown]
# ## StandardScaler for scaling Features

# %%
# Importing StandardScaler
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X
# Out:
#       Restaurant ID  Restaurant Name  Country Code      City   Address  \
# 0         -0.277386         0.052689     11.616901 -0.498280  1.612139
# 1         -0.278877        -0.226145     11.616901 -0.498280  0.523697
# 2         -0.279356        -0.355245     11.616901 -0.381656 -0.040436
# 3         -0.277289         0.491312     11.616901 -0.381656  1.614327
# 4         -0.277759         0.876496     11.616901 -0.381656  1.613889
# ...             ...              ...           ...       ...       ...
# 8560      -0.290304        -0.674292     11.616901 -2.131029 -1.183147
# 8561      -0.290398         1.656387     11.616901 -2.131029 -1.405912
# 8562       1.056489         0.847925     11.616901 -2.131029  0.285615
# 8563      -0.290372         0.545809     11.616901 -2.131029 -0.366050
# 8564       1.062922         0.817766     11.616901 -2.131029  1.551305
#
#       Locality  Locality Verbose  Longitude  Latitude  Cuisines   Currency  \
# ...

# %% [markdown]
# ## Variance Inflation Factor (VIF)

# %%
# Importing Variance Inflation Factor
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["variables"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif
# Out:
#               variables         VIF
# 0         Restaurant ID    1.543839
# 1       Restaurant Name    1.010052
# 2          Country Code   14.127357
# 3                  City    1.087150
# 4               Address    1.066788
# 5              Locality  510.273286
# 6      Locality Verbose  510.243194
# 7             Longitude    8.613685
# 8              Latitude    8.813468
# 9              Cuisines    1.029211
# 10             Currency    1.577230
# 11    Has Table booking    1.587505
# 12  Has Online delivery    1.278349
# 13    Is delivering now    1.015787
# 14          Price range    2.029623
# 15     Aggregate rating    5.231459
# 16         Rating color    1.258799
# 17          Rating text    1.596227
# 18                Votes    6.336284
# 19              Country   14.197434

# %%
X.drop("Locality",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["variables"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif
# Out:
#               variables        VIF
# 0         Restaurant ID   1.543546
# 1       Restaurant Name   1.010046
# 2          Country Code  14.125832
# 3                  City   1.080566
# 4               Address   1.065840
# 5      Locality Verbose   1.055275
# 6             Longitude   8.605442
# 7              Latitude   8.805869
# 8              Cuisines   1.028659
# 9              Currency   1.577227
# 10    Has Table booking   1.587056
# 11  Has Online delivery   1.277240
# 12    Is delivering now   1.015785
# 13          Price range   2.026171
# 14     Aggregate rating   5.229220
# 15         Rating color   1.258752
# 16          Rating text   1.596054
# 17                Votes   6.327624
# 18              Country  14.192896

# %%
X.drop("Country Code",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["variables"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif
# Out:
#               variables       VIF
# 0         Restaurant ID  1.543538
# 1       Restaurant Name  1.009700
# 2                  City  1.076915
# 3               Address  1.064566
# 4      Locality Verbose  1.055266
# 5             Longitude  8.604765
# 6              Latitude  8.801771
# 7              Cuisines  1.028632
# 8              Currency  1.486374
# 9     Has Table booking  1.584614
# 10  Has Online delivery  1.275360
# 11    Is delivering now  1.015785
# 12          Price range  2.025078
# 13     Aggregate rating  5.228626
# 14         Rating color  1.251268
# 15          Rating text  1.591368
# 16                Votes  6.320603
# 17              Country  1.405965

# %% [markdown]
# # Finding Best Model
#
# ## 2. REGRESSION:
#
# - **RandomForestRegressor**
#
# - **Decision Tree Regressor**
#
# - **AdaBoostRegressor**
#
# - **Gradient Boosting Regressor**
#
# - **Bagging Regressor**

# %%
# Importing required liabraries for regressor problem
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import metrics

# %%
maxAccu = 0
maxRS = 0
for i in range(1,200):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=.20, random_state=i)
    mod = RandomForestRegressor()
    mod.fit(X_train, Y_train)
    pred = mod.predict(X_test)
    acc = r2_score(Y_test, pred)
    if acc > maxAccu:
        maxAccu=acc
        maxRS = i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.8807120981466252  on Random_state  134

# %% [markdown]
# ### RandomForestRegressor

# %%
RF = RandomForestRegressor()
RF.fit(X_train,Y_train)
print('==============================================================================================')
predrf = RF.predict(X_test)
print('R2_Score:',r2_score(Y_test,predrf))
print('==============================================================================================')
print('MAE:',metrics.mean_absolute_error(Y_test, predrf))
print('MSE:',metrics.mean_squared_error(Y_test, predrf))
print("RMSE:",np.sqrt(metrics.mean_squared_error(Y_test, predrf)))
# Out:
# ...
# R2_Score: 0.8433083489008086
# ...
# MAE: 0.2670509045985872
# MSE: 0.14632808790448146
# RMSE: 0.38252854521523155

# %% [markdown]
# ### DecisionTreeRegressor

# %%
# Checking R2 score for Decision Tree Regressor
DT = DecisionTreeRegressor()
DT.fit(X_train,Y_train)
print('==============================================================================================')
# prediction
preddt = DT.predict(X_test)
print('R2_Score:',r2_score(Y_test,preddt))
print('==============================================================================================')
# Metric evaluation
print('MAE:',metrics.mean_absolute_error(Y_test, preddt))
print('MSE:',metrics.mean_squared_error(Y_test, preddt))
print("RMSE:",np.sqrt(metrics.mean_squared_error(Y_test, preddt)))
# Out:
# ...
# R2_Score: 0.7034681537014853
# ...
# MAE: 0.34868598382026705
# MSE: 0.2769192727708207
# RMSE: 0.5262311970710409

# %% [markdown]
# ### GradientBoosting Regressor

# %%
# Checking R2 score for Decision Tree Regressor
GBR = GradientBoostingRegressor()
GBR.fit(X_train,Y_train)
print('==============================================================================================')
# prediction
preddt = GBR.predict(X_test)
print('R2_Score:',r2_score(Y_test,preddt))
print('==============================================================================================')
# Metric evaluation
print('MAE:',metrics.mean_absolute_error(Y_test, preddt))
print('MSE:',metrics.mean_squared_error(Y_test, preddt))
print("RMSE:",np.sqrt(metrics.mean_squared_error(Y_test, preddt)))
# Out:
# ...
# R2_Score: 0.8470103620601511
# ...
# MAE: 0.2773007822433414
# MSE: 0.14287092536133553
# RMSE: 0.3779827051087596

# %% [markdown]
# ### BaggingRegressor

# %%
# Checking R2 score for Decision Tree Regressor
BR = BaggingRegressor()
BR.fit(X_train,Y_train)
print('==============================================================================================')
# prediction
preddt = BR.predict(X_test)
print('R2_Score:',r2_score(Y_test,preddt))
print('==============================================================================================')
# Metric evaluation
print('MAE:',metrics.mean_absolute_error(Y_test, preddt))
print('MSE:',metrics.mean_squared_error(Y_test, preddt))
print("RMSE:",np.sqrt(metrics.mean_squared_error(Y_test, preddt)))
# Out:
# ...
# R2_Score: 0.8341484232493868
# ...
# MAE: 0.27452148438232005
# MSE: 0.1548821773950012
# RMSE: 0.3935507303957156

# %% [markdown]
# ### AdaBoostRegressor

# %%
# Checking R2 score for Decision Tree Regressor
ABR = AdaBoostRegressor()
ABR.fit(X_train,Y_train)
print('==============================================================================================')
# prediction
preddt = ABR.predict(X_test)
print('R2_Score:',r2_score(Y_test,preddt))
print('==============================================================================================')
# Metric evaluation
print('MAE:',metrics.mean_absolute_error(Y_test, preddt))
print('MSE:',metrics.mean_squared_error(Y_test, preddt))
print("RMSE:",np.sqrt(metrics.mean_squared_error(Y_test, preddt)))
# Out:
# ...
# R2_Score: 0.724779003406534
# ...
# MAE: 0.41846026366788364
# MSE: 0.25701791959032794
# RMSE: 0.5069693477818239

# %% [markdown]
# ## Cross-Validation

# %%
# Checking cv score for Random Forest Regressor
print('Random Forest:',cross_val_score(RF,X,Y,cv=5).mean())
print('==================================================')

# Checking cv score for Decision Tree Regressor
print('Decision Tree:',cross_val_score(DT,X,Y,cv=5).mean())
print('==================================================')

# Checking cv score for Gradient Boosting Regressor
print('Gradient Boosting:',cross_val_score(GBR,X,Y,cv=5).mean())
print('==================================================')

# Checking cv score for AdaBoostRegressor
print('Bagging Regressor:',cross_val_score(ABR,X,Y,cv=5).mean())
print('==================================================')

# Checking cv score for BaggingRegressor
print('ExtraTreesRegressor:',cross_val_score(BR,X,Y,cv=5).mean())
print('==================================================')
# Out:
# Random Forest: -0.54183306377818
# ...
# Decision Tree: -2.6789471127480438
# ...
# Gradient Boosting: -0.08026219512985425
# ...
# Bagging Regressor: 0.5798325279018524
# ...
# ExtraTreesRegressor: -0.41528008046675735
# ...

# %% [markdown]
# # Hyper parameter tuning

# %%
# Importing required liabraries
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error,mean_absolute_error

from sklearn.metrics import r2_score

# %%
RF = RandomForestRegressor()

param ={
       'n_estimators':[100,200],
      'criterion':['mse','mae'],
     'min_samples_split':[2],
    'min_samples_leaf':[1],
}

# %%
RF_grid=GridSearchCV(RandomForestRegressor(),param,cv=4,scoring='accuracy',n_jobs=-1,verbose=2)

# %%
RF_grid.fit(X_train,Y_train)
RF_grid_PRED=RF_grid.best_estimator_.predict(X_test)
# Out:
# Fitting 4 folds for each of 4 candidates, totalling 16 fits

# %%
RF_grid.best_params_
# Out:
# {'criterion': 'mse',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
print('MSE:',mean_squared_error(RF_grid_PRED,Y_test))
print('MAE:',mean_absolute_error(RF_grid_PRED,Y_test))
print ('==============================================')
print('r2_score:',r2_score(RF_grid_PRED,Y_test))
print ('==============================================')
# Out:
# MSE: 0.14695955188031434
# MAE: 0.26644988749139675
# ...
# r2_score: 0.820097357576593
# ...

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(RF_grid,"Average Cost for two.pkl")
# Out:
# ['Average Cost for two.pkl']

# %% [markdown]
# Accuracy score is arround 82% for regressor and Accuracy after tuning for clasifier is 98%
